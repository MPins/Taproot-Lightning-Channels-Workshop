# %% [markdown]
# # Creating a Collaborative Closing Transaction
#
# In this section, we'll build a lightning channel closing transaction from scratch using Python. We'll walk through each part of the transaction — how it's constructed, signed, and the messages exchanged between peers to coordinate the close. The process will be tested using Bitcoin Core in regtest mode.

# %% [markdown]
# ## Setup
#
# For this notebook, we’ll use the Chapter 1 – Channel Funding Transaction, where the funding transaction was created and confirmed on our regtest blockchain.

# %%
# %run "../chapter 1 - channel funding transaction/funding transaction.ipynb"
# Out:
# 2025-11-12T15:07:32.283000Z TestFramework (INFO): PRNG seed is: 8616277493977653466
# 2025-11-12T15:07:32.284000Z TestFramework (INFO): Initializing test directory /tmp/bitcoin_func_test_vkxz7p_2
# 🟢 New TestShell started. Block height: 0
# Alice Per Commitment Seed 34b581ec20bf2c6cae3d4d4dcbfddc8a3727a1e9a57c55f3520e770607898c06
# Bob Per Commitment Seed 89c994b3ddad4698acee71e42d8bcace48eea739caaba371eb110e77663ec56d
# Alice Payment BasePoint:  025f892a06124391e2f38ce35d943cdc09f63e203330dbd9cb6113a903e0738458
# Bob Payment BasePoint:  02f98efd3f2b2fbe7bd83c419f5f64f8280798b8a9175fdb77c0091bbb95c79506
# To obscure commitment number 0xb433fd43a66f
# Alice funding pubkey: 0ec50c8be3d8493cdf4663e75eb09badaeab417605ef7afda5497eea77fefec9
# Alice funding privkey: e6eaca1102b8116b17fd58abb96c921514e45d4e14da078d28b3bde9b007976e
# Alice funding address: bcrt1ppmzsezlrmpyneh6xv0n4avym4kh2kstkqhhh4ld9f9lw5al7lmysq9dm63
# Bob funding pubkey: f3a694638a57250fd8ad7ca58de477eb14cd580e2aba21ea61e8e2c45337f807
# Bob funding privkey: bd8d3f6b92a4b320465bf59b31d54b009e998fc4e2443d2a075201c991f55575
# Bob funding address: bcrt1p7wnfgcu22ujslk9d0jjcmerhav2v6kqw92azr6npar3vg5ehlqrsentv0w
# Transaction creating Alice UTXO: 6dc22f2ef55d20718d8fa2f208ec345850ba3035812b5ec8d2fbffb823de904c
# {
#   "txid": "6dc22f2ef55d20718d8fa2f208ec345850ba3035812b5ec8d2fbffb823de904c",
#   "hash": "6bf06f5db8f35e7c28315523cfa125797e89ee49d9b6f37abd7d4bf722b7a6df",
#   "version": 2,
#   "size": 289,
#   "vsize": 208,
#   "weight": 829,
#   "locktime": 51,
#   "vin": [
#     {
#       "txid": "aa3d2f268b7bf357dc261b70a126559a516851304995aa046dc27b6b634e4d42",
#       "vout": 0,
#       "scriptSig": {
#         "asm": "",
#         "hex": ""
#       },
#       "txinwitness": [
#         "3044022073da4fea167969a53f3b7d05081bd75765823bc8b19eece10fb001a8dc653a54022047ba9f18d559c417349547564f3c8b3961fb0f51bc030fe0ac0cd87cbb2129f701",
#         "0377631073554777a7eed73b9a06f04a50ebb68507a1f48e7346928d487da246f8"
#       ],
#       "sequence": 4294967293
#     }
#   ],
#   "vout": [
#     {
#       "value": "1.00000000",
#       "n": 0,
#       "scriptPubKey": {
#         "asm": "1 0ec50c8be3d8493cdf4663e75eb09badaeab417605ef7afda5497eea77fefec9",
#         "desc": "rawtr(0ec50c8be3d8493cdf4663e75eb09badaeab417605ef7afda5497eea77fefec9)#u8hn9u29",
#         "hex": "51200ec50c8be3d8493cdf4663e75eb09badaeab417605ef7afda5497eea77fefec9",
#         "address": "bcrt1ppmzsezlrmpyneh6xv0n4avym4kh2kstkqhhh4ld9f9lw5al7lmysq9dm63",
#         "type": "witness_v1_taproot"
#       }
#     },
#     {
#       "value": "47.99995840",
#       "n": 1,
#       "scriptPubKey": {
#         "asm": "1 8427c19d6cf49de409ab6b2f0713f44faabecf1696abf3170b39790a28b3b730",
#         "desc": "rawtr(8427c19d6cf49de409ab6b2f0713f44faabecf1696abf3170b39790a28b3b730)#ddj5k6q8",
#         "hex": "51208427c19d6cf49de409ab6b2f0713f44faabecf1696abf3170b39790a28b3b730",
#         "address": "bcrt1pssnur8tv7jw7gzdtdvhswyl5f74tanckj64lx9ct89us529nkucqky7fr0",
#         "type": "witness_v1_taproot"
#       }
#     },
#     {
#       "value": "1.00000000",
#       "n": 2,
#       "scriptPubKey": {
#         "asm": "1 f3a694638a57250fd8ad7ca58de477eb14cd580e2aba21ea61e8e2c45337f807",
#         "desc": "rawtr(f3a694638a57250fd8ad7ca58de477eb14cd580e2aba21ea61e8e2c45337f807)#u35pl2tx",
#         "hex": "5120f3a694638a57250fd8ad7ca58de477eb14cd580e2aba21ea61e8e2c45337f807",
#         "address": "bcrt1p7wnfgcu22ujslk9d0jjcmerhav2v6kqw92azr6npar3vg5ehlqrsentv0w",
#         "type": "witness_v1_taproot"
#       }
#     }
#   ],
#   "hex": "..."
# }
# Alice transaction to spend: 6dc22f2ef55d20718d8fa2f208ec345850ba3035812b5ec8d2fbffb823de904c:0
# Alice funding pubkey: 4045b56e1e4afa0275a4a172e2cd1a6c5b1d3c8f33dfab2bd2322bb84e245895
# Alice funding privkey: 804ea245cb1ab61561b5b20332fea92b42e6f490a61d05f4845566f594b484d0
# Alice funding address: bcrt1pgpzm2ms7ftaqyady59ew9ng6d3d360y0x006k27jxg4msn3ytz2s7punq5
# Alice MuSig2 pubkey: da343ac1cf4da02951db730490842a078e8468af25b48451b448621ef106e093
# Alice MuSig2 privkey: 38c85990f1b1477df1c9888d8fb85532eb0110c823e3c99c4590a4649526c3f8
# Bob MuSig2 pubkey: c6327a1c2b0a44359f673be9faffc94a9f593c35ad47fce0e67251d6efaffda9
# Bob MuSig2 privkey: 08142febada3087afb8166d6818d55cf6061d65e0a9f01741da4cb0398eab11f
# Aggregate musig2 pubkey: 3a482cf6a7ecf6573ec1271d2441c8457c87dc2834e39c37f6408638c9f35717
# Channel funding musig2 output address: bcrt1p8fyzea48anm9w0kpyuwjgswgg47g0hpgxn3ecdlkgzrr3j0n2utsty0r3n
# unsigned_tx:  
# {
#   "txid": "e306aea607061c113e7b534c4725d8cd8acb7ad9d76a365aa37d4cababf327c6",
#   "hash": "e306aea607061c113e7b534c4725d8cd8acb7ad9d76a365aa37d4cababf327c6",
#   "version": 2,
#   "size": 137,
#   "vsize": 137,
#   "weight": 548,
#   "locktime": 0,
#   "vin": [
#     {
#       "txid": "6dc22f2ef55d20718d8fa2f208ec345850ba3035812b5ec8d2fbffb823de904c",
#       "vout": 0,
#       "scriptSig": {
#         "asm": "",
#         "hex": ""
#       },
#       "sequence": 4294967295
#     }
#   ],
#   "vout": [
#     {
#       "value": "0.01000000",
#       "n": 0,
#       "scriptPubKey": {
#         "asm": "1 3a482cf6a7ecf6573ec1271d2441c8457c87dc2834e39c37f6408638c9f35717",
#         "desc": "rawtr(3a482cf6a7ecf6573ec1271d2441c8457c87dc2834e39c37f6408638c9f35717)#8080xhvh",
#         "hex": "51203a482cf6a7ecf6573ec1271d2441c8457c87dc2834e39c37f6408638c9f35717",
#         "address": "bcrt1p8fyzea48anm9w0kpyuwjgswgg47g0hpgxn3ecdlkgzrr3j0n2utsty0r3n",
#         "type": "witness_v1_taproot"
#       }
#     },
#     {
#       "value": "0.98999700",
#       "n": 1,
#       "scriptPubKey": {
#         "asm": "1 4045b56e1e4afa0275a4a172e2cd1a6c5b1d3c8f33dfab2bd2322bb84e245895",
#         "desc": "rawtr(4045b56e1e4afa0275a4a172e2cd1a6c5b1d3c8f33dfab2bd2322bb84e245895)#yuljjgz4",
#         "hex": "51204045b56e1e4afa0275a4a172e2cd1a6c5b1d3c8f33dfab2bd2322bb84e245895",
#         "address": "bcrt1pgpzm2ms7ftaqyady59ew9ng6d3d360y0x006k27jxg4msn3ytz2s7punq5",
#         "type": "witness_v1_taproot"
#       }
#     }
#   ]
# }
# signed tx:  ...
# {
#   "txid": "e306aea607061c113e7b534c4725d8cd8acb7ad9d76a365aa37d4cababf327c6",
#   "hash": "818acc0d058f079b5797b6bc7c749091c243751b79818e7dabf33842b36256fa",
#   "version": 2,
#   "size": 205,
#   "vsize": 154,
#   "weight": 616,
#   "locktime": 0,
#   "vin": [
#     {
#       "txid": "6dc22f2ef55d20718d8fa2f208ec345850ba3035812b5ec8d2fbffb823de904c",
#       "vout": 0,
#       "scriptSig": {
#         "asm": "",
#         "hex": ""
#       },
#       "txinwitness": [
#         "c888f2623d5f4eb7366ed35c8306fc040ccb410cb03d791a3209ea68b9d9d946536532d419975162e1cae1176f1144fb7b0e3e2098bbeb29a60a76d54df5ef4c"
#       ],
#       "sequence": 4294967295
#     }
#   ],
#   "vout": [
#     {
#       "value": "0.01000000",
#       "n": 0,
#       "scriptPubKey": {
#         "asm": "1 3a482cf6a7ecf6573ec1271d2441c8457c87dc2834e39c37f6408638c9f35717",
#         "desc": "rawtr(3a482cf6a7ecf6573ec1271d2441c8457c87dc2834e39c37f6408638c9f35717)#8080xhvh",
#         "hex": "51203a482cf6a7ecf6573ec1271d2441c8457c87dc2834e39c37f6408638c9f35717",
#         "address": "bcrt1p8fyzea48anm9w0kpyuwjgswgg47g0hpgxn3ecdlkgzrr3j0n2utsty0r3n",
#         "type": "witness_v1_taproot"
#       }
#     },
#     {
#       "value": "0.98999700",
#       "n": 1,
#       "scriptPubKey": {
#         "asm": "1 4045b56e1e4afa0275a4a172e2cd1a6c5b1d3c8f33dfab2bd2322bb84e245895",
#         "desc": "rawtr(4045b56e1e4afa0275a4a172e2cd1a6c5b1d3c8f33dfab2bd2322bb84e245895)#yuljjgz4",
#         "hex": "51204045b56e1e4afa0275a4a172e2cd1a6c5b1d3c8f33dfab2bd2322bb84e245895",
#         "address": "bcrt1pgpzm2ms7ftaqyady59ew9ng6d3d360y0x006k27jxg4msn3ytz2s7punq5",
#         "type": "witness_v1_taproot"
#       }
#     }
#   ]
# }
# funding_channel_txid:  e306aea607061c113e7b534c4725d8cd8acb7ad9d76a365aa37d4cababf327c6

# %% [markdown]
# ## Setup Alice and Bob Funding Outputs
#
# Create Taproot addresses for Alice and Bob so they have to send the funds from the simple Taproot channel.

# %%
# Create a new Alice key pair for channel funding multisig output
alice_closing_privkey, alice_closing_pubkey = generate_bip340_key_pair()
# Derive the bech32 address
# Use program_to_witness(version_int, pubkey_bytes)
alice_closing_address = program_to_witness(0x01, alice_closing_pubkey.get_bytes())
print(f"Alice closing pubkey: {alice_closing_pubkey.get_bytes().hex()}")
print(f"Alice closing privkey: {alice_closing_privkey.get_bytes().hex()}")
print(f"Alice closing address: {alice_closing_address}")

# Create a new Bob key pair for channel funding multisig output
bob_closing_privkey, bob_closing_pubkey = generate_bip340_key_pair()
# Derive the bech32 address
# Use program_to_witness(version_int, pubkey_bytes)
bob_closing_address = program_to_witness(0x01, bob_closing_pubkey.get_bytes())
print(f"Bob closing pubkey: {bob_closing_pubkey.get_bytes().hex()}")
print(f"Bob closing privkey: {bob_closing_privkey.get_bytes().hex()}")
print(f"Bob closing address: {bob_closing_address}")
# Out:
# Alice closing pubkey: 03962996f825ca120667badbaf2a1700620213675f8a166deaa33f534fd4c698
# Alice closing privkey: 1458decce9b2d5a9bf687405b84e917421c245c9801ec807a620bb8f28ec9751
# Alice closing address: bcrt1pqwtzn9hcyh9pypn8htd672shqp3qyym8t79pvm025vl4xn75c6vqnr9aqv
# Bob closing pubkey: f9c7406f2ad2db5a0379c1113433cbdcec00dbdd2676394bcead20fa66c686b3
# Bob closing privkey: bedc18b908a735ee78bd271ce55aa30a76be97b2493a7561af6144824f8ebaf8
# Bob closing address: bcrt1pl8r5qme26td45qmecygngv7tmnkqpk7ayemrjj7w45s05ekxs6esz23c76

# %% [markdown]
# ## Legacy cooperative closure
#
# Compared to the base segwit v0 channel type, for simple taproot channels, the co-op close transaction now always signals RBF. In other words, the sequence field of the sole input to the cooperative close transaction MUST be less-than-or-equal to 0xfffffffd. This enables a future cooperative closure flow to support increasing the fee of subsequent close offers via RBF.
#
# In addition, rather than adopt the existing cooperative closure fee rate "negotiation", the responder SHOULD now always accept the offer sent by the initiator. In other words, the cooperative close process now terminates after exactly 1 RTTs: initiator sends sigs with offer, with the responder echo'ing back the same fee rate. This serves to ensure that the co-op close process always terminates deterministically, and also plays nicer with the nonces: only a single message is ever signed by both sides for a coop close workflow.
#
#     +-----------+                                        +---------+
#     |           |--(1)-------- shutdown (nonce) -------->|         |
#     |           |<-(2)-------- shutdown (nonce) ---------|         |
#     |           |                                        |         |
#     |   Alice   |--(3)-- closing_signed (partial sig) -->|   Bob   |
#     |           |<-(4)-- closing_signed (partial sig) ---|         |
#     |           |                                        |         |
#     |           |                                        |         |
#     |           |                                        |         |
#     +-----------+                                        +---------+
#
# ## Modern RBF-based cooperative close
#
# For taproot channels supporting RBF cooperative close, nonces are delivered just-in-time (JIT) with signatures using an asymmetric pattern:
#
# During the initial exchange phase, each party includes its closee nonce within the shutdown message. This nonce represents the one that the node will later use when signing as the closee in a cooperative close. By exchanging these nonces in advance, both participants ensure that the remote party possesses the correct verification data to construct and verify the closing transaction when acting as the closer. This mechanism simplifies the cooperative close process by avoiding the need for additional nonce exchanges at the time of closure.
#
# ### RBF Iterations: Subsequent nonces are delivered with signatures
#
# * closing_complete (from closer): uses partial_sig_w_nonce bundles the partial signature with the sender's closer nonce. The bundling is necessary because the closee doesn't know this nonce yet.
#
# * closing_sig (from closee): uses partial_sig plus nonce (NextCloseeNonce) field
#
# Asymmetric Roles:
#
# * Closer: The party sending closing_complete, proposing a new fee
# * Closee: The party sending closing_sig, accepting the fee proposal
#
# Each party alternates between these roles during RBF iterations.
#
#     +-----------+                                                         +---------+
#     |           |--(1)-------------- shutdown (next nonce) -------------->|         |
#     |           |<-(2)-------------- shutdown (next nonce) ---------------|         |
#     |           |                                                         |         |
#     |   Alice   |--(3)--- closing_complete (partial sig) (jit nonce) ---->|   Bob   |
#     |           |<-(4)----- closing_sig (partial sig) (next nonce) -------|         |
#     |           |                                                         |         |
#     |           |<-(5)--- closing_complete (partial sig) (jit nonce) -----|         |
#     |           |--(6)------- closing_sig (partial sig) (next nonce) ---->|         |
#     |           |                                                         |         |
#     +-----------+                                                         +---------+

# %% [markdown]
# ## The Unsined Transaxaction

# %%
# VERSION
# version '2' indicates that we may use relative timelocks (BIP68)
version = bytes.fromhex("0200 0000")

# MARKER (new to segwit)
marker = bytes.fromhex("00")

# FLAG (new to segwit)
flag = bytes.fromhex("01")

# INPUTS
# We have just 1 input
input_count = bytes.fromhex("01")

# Convert txid and index to bytes (little endian)
txid = (bytes.fromhex(funding_channel_txid))[::-1]
funding_channel_index = 0
index = funding_channel_index.to_bytes(4, byteorder="little", signed=False)

# For the unsigned transaction we use an empty scriptSig
scriptsig = bytes.fromhex("")

# Use `0xfffffffd` to enable a future rbf cooperative closure round
sequence = bytes.fromhex("fdff ffff")

inputs = (
    txid
    + index
    + varint_len(scriptsig)
    + scriptsig
    + sequence
)

# OUTPUTS
# 0x02 for out two outputs
output_count = bytes.fromhex("02")

# Transaction Fee
tx_fee_sat = int(float("0.00000300") * 100000000)

# OUTPUT 1 - Back to Alice
# 0.005 BTC discounted the fees
# In the legacy cooperative closure the channel founder pay the fees
# In the new rbf cooperative closure the closer pay the fees
output1_value_sat = int(float("0.005") * 100000000) - tx_fee_sat
output1_value = output1_value_sat.to_bytes(8, byteorder="little", signed=False)
# scriptPubKey P2TR: OP_1 (0x51) + PUSH32 (0x20) + xonly(32B)
output1_spk = bytes.fromhex("51") + varint_len(alice_closing_pubkey.get_bytes()) + alice_closing_pubkey.get_bytes()

# OUTPUT 2 - Back to Bob
# 0.005 BTC
output2_value_sat = int(float("0.005") * 100000000)
output2_value = output2_value_sat.to_bytes(8, byteorder="little", signed=False)
# scriptPubKey P2TR: OP_1 (0x51) + PUSH32 (0x20) + xonly(32B)
output2_spk = bytes.fromhex("51") + varint_len(bob_closing_pubkey.get_bytes()) + bob_closing_pubkey.get_bytes()

outputs = (
    output1_value
    + varint_len(output1_spk)
    + output1_spk
    + output2_value
    + varint_len(output2_spk)
    + output2_spk
)

# LOCKTIME
locktime = bytes.fromhex("0000 0000")

unsigned_tx = (
    version
    + input_count
    + inputs
    + output_count
    + outputs
    + locktime
)
print("unsigned_tx: ", unsigned_tx.hex())

# Decode the unsigned transaction to verify it looks correct
decoded = node.decoderawtransaction(unsigned_tx.hex())
print(json.dumps(decoded, indent=2, default=str))
# Out:
# unsigned_tx:  
# {
#   "txid": "7b83f91080ff7b7468d58ba0310d1076935266144e58fa84c732ad2f40b422ac",
#   "hash": "7b83f91080ff7b7468d58ba0310d1076935266144e58fa84c732ad2f40b422ac",
#   "version": 2,
#   "size": 137,
#   "vsize": 137,
#   "weight": 548,
#   "locktime": 0,
#   "vin": [
#     {
#       "txid": "e306aea607061c113e7b534c4725d8cd8acb7ad9d76a365aa37d4cababf327c6",
#       "vout": 0,
#       "scriptSig": {
#         "asm": "",
#         "hex": ""
#       },
#       "sequence": 4294967293
#     }
#   ],
#   "vout": [
#     {
#       "value": "0.00499700",
#       "n": 0,
#       "scriptPubKey": {
#         "asm": "1 03962996f825ca120667badbaf2a1700620213675f8a166deaa33f534fd4c698",
#         "desc": "rawtr(03962996f825ca120667badbaf2a1700620213675f8a166deaa33f534fd4c698)#v4r26yh2",
#         "hex": "512003962996f825ca120667badbaf2a1700620213675f8a166deaa33f534fd4c698",
#         "address": "bcrt1pqwtzn9hcyh9pypn8htd672shqp3qyym8t79pvm025vl4xn75c6vqnr9aqv",
#         "type": "witness_v1_taproot"
#       }
#     },
#     {
#       "value": "0.00500000",
#       "n": 1,
#       "scriptPubKey": {
#         "asm": "1 f9c7406f2ad2db5a0379c1113433cbdcec00dbdd2676394bcead20fa66c686b3",
#         "desc": "rawtr(f9c7406f2ad2db5a0379c1113433cbdcec00dbdd2676394bcead20fa66c686b3)#4vl2547v",
#         "hex": "5120f9c7406f2ad2db5a0379c1113433cbdcec00dbdd2676394bcead20fa66c686b3",
#         "address": "bcrt1pl8r5qme26td45qmecygngv7tmnkqpk7ayemrjj7w45s05ekxs6esz23c76",
#         "type": "witness_v1_taproot"
#       }
#     }
#   ]
# }

# %% [markdown]
# ## The sighash for the key path spend
#
# This is the “Schnorr key spend” case: you’re proving knowledge of the (tweaked) internal private key, with no script branch revealed. The message preimage is called msg_digest in [BIP-341](https://github.com/bitcoin/bips/blob/master/bip-0341.mediawiki).

# %%
index_of_this_input = bytes.fromhex("0000 0000")

# SIGHASH for key path spend
# See BIP-341 for details
sighash_epoch = bytes.fromhex("00")

# Control
hash_type = bytes.fromhex("00") # SIGHASH_DEFAULT (a new sighash type meaning implied SIGHASH_ALL)

# Transaction data
sha_prevouts = sha256(txid + index).digest()

sha_amounts = sha256(channel_value).digest()

# scriptPubKey P2TR: OP_1 (0x51) + PUSH32 (0x20) + xonly(32B)
sha_scriptpubkeys = sha256(
    varint_len(channel_spk)
    + channel_spk
).digest()

sha_sequences = sha256(sequence).digest()

sha_outputs = sha256(outputs).digest()

# Data about this input
spend_type = bytes.fromhex("00") # no annex present

sig_msg = (
    sighash_epoch
    + hash_type
    + version
    + locktime
    + sha_prevouts
    + sha_amounts
    + sha_scriptpubkeys
    + sha_sequences
    + sha_outputs
    + spend_type
    + index_of_this_input
)

tag_hash = sha256("TapSighash".encode()).digest()
sighash = sha256(tag_hash + tag_hash + sig_msg).digest()

# %% [markdown]
# ## Signing the sighash

# %%
# Build participants to sort them using the same rule used in pubkeys aggregation.
participants = [
    (pubkey_alice_musig2.get_bytes(bip340=False), privkey_alice_musig2.get_bytes()),
    (pubkey_bob_musig2.get_bytes(bip340=False),   privkey_bob_musig2.get_bytes()),
]

# Reorder participants to match the sorted pubkeys
pk_to_tuple = {pk: (pk, sk) for pk, sk in participants}
participants = [pk_to_tuple[pk] for pk in sorted_pubkeys]

# Alice and Bob generates its own nonce pair (secnonce, pubnonce)
secnonces, pubnonces = [], []
for pk, sk in participants:
    sec, pub = nonce_gen(sk, pk, agg_pubkey_tweaked, sighash, None)
    secnonces.append(sec)
    pubnonces.append(pub)

# Alice and Bob has exchanged already the pubnonces, so they can agregate them and create the session context
agg_nonce = nonce_agg(pubnonces)
session = SessionContext(agg_nonce, sorted_pubkeys, [bip86_tweak], [True], sighash)

# Alice and Bob produces their partial signatures
# Partial signatures in the SAME order as pubkeys/participants
psigs = [sign(sec, sk, session) for sec, (_, sk) in zip(secnonces, participants)]

# Each side verify the other’s partial signature before proceeding
for i, psig in enumerate(psigs):
    assert partial_sig_verify(psig, pubnonces, sorted_pubkeys, [bip86_tweak], [True], sighash, i)

# Each side combines partial signatures into the final Schnorr signature
agg_sig = partial_sig_agg(psigs, session)

# Sanity check: verify with BIP340 against the *tweaked* x-only key ---
ok = schnorr_verify(sighash, agg_pubkey_tweaked, agg_sig)
print("aggregated Schnorr verifies?", ok)
# Out:
# aggregated Schnorr verifies? True

# %% [markdown]
# ## The signed transaction

# %%
witness = (
    bytes.fromhex("01") # one stack item in the witness
    + varint_len(agg_sig)
    + agg_sig
)

# the final signed transaction
signed_tx = (
    version
    + marker
    + flag
    + input_count
    + inputs
    + output_count
    + outputs
    + witness
    + locktime
)

print("signed tx: ",signed_tx.hex())
# Decode the unsigned transaction to verify it looks correct
decoded = node.decoderawtransaction(signed_tx.hex())
print(json.dumps(decoded, indent=2, default=str))

coopclose_txid = node.sendrawtransaction(signed_tx.hex())
result = node.generatetoaddress(nblocks=1, address=address, called_by_framework=True)

print("coopclose_txid: ", coopclose_txid)
# Out:
# signed tx:  ...
# {
#   "txid": "7b83f91080ff7b7468d58ba0310d1076935266144e58fa84c732ad2f40b422ac",
#   "hash": "70cd115726f37471b340ad2f755363db75fca0dea941ffa95df141dc43fe5d51",
#   "version": 2,
#   "size": 205,
#   "vsize": 154,
#   "weight": 616,
#   "locktime": 0,
#   "vin": [
#     {
#       "txid": "e306aea607061c113e7b534c4725d8cd8acb7ad9d76a365aa37d4cababf327c6",
#       "vout": 0,
#       "scriptSig": {
#         "asm": "",
#         "hex": ""
#       },
#       "txinwitness": [
#         "0dd67809b387256bd2f092b9c254c8db52103fbd93519ce7d896499223aa53949f475f8d50d339f3a16c1159a5f47406234fe5a6b80ce2bb72fe5d43e138ced9"
#       ],
#       "sequence": 4294967293
#     }
#   ],
#   "vout": [
#     {
#       "value": "0.00499700",
#       "n": 0,
#       "scriptPubKey": {
#         "asm": "1 03962996f825ca120667badbaf2a1700620213675f8a166deaa33f534fd4c698",
#         "desc": "rawtr(03962996f825ca120667badbaf2a1700620213675f8a166deaa33f534fd4c698)#v4r26yh2",
#         "hex": "512003962996f825ca120667badbaf2a1700620213675f8a166deaa33f534fd4c698",
#         "address": "bcrt1pqwtzn9hcyh9pypn8htd672shqp3qyym8t79pvm025vl4xn75c6vqnr9aqv",
#         "type": "witness_v1_taproot"
#       }
#     },
#     {
#       "value": "0.00500000",
#       "n": 1,
#       "scriptPubKey": {
#         "asm": "1 f9c7406f2ad2db5a0379c1113433cbdcec00dbdd2676394bcead20fa66c686b3",
#         "desc": "rawtr(f9c7406f2ad2db5a0379c1113433cbdcec00dbdd2676394bcead20fa66c686b3)#4vl2547v",
#         "hex": "5120f9c7406f2ad2db5a0379c1113433cbdcec00dbdd2676394bcead20fa66c686b3",
#         "address": "bcrt1pl8r5qme26td45qmecygngv7tmnkqpk7ayemrjj7w45s05ekxs6esz23c76",
#         "type": "witness_v1_taproot"
#       }
#     }
#   ]
# }
# coopclose_txid:  7b83f91080ff7b7468d58ba0310d1076935266144e58fa84c732ad2f40b422ac
