# %% [markdown]
# # Creating the Commitment Transaction with in-flight htlc
#
# In this section, we'll build a lightning channel commitment v3 transaction with in-flight htlc from scratch using Python. We'll walk through each part of the transaction — how it's constructed and signed. The process will be tested using Bitcoin Core in regtest mode.

# %% [markdown]
# ## Setup
#
# For this notebook, we’ll use the basepoints derivated in the `chapter 0 - lightning node keys derivation` the funding transaction created in the `chapter 1 - channel funding transaction` and parts of the first commitment transaction created in the `chapter 2 - initial commitment transaction v3`.

# %%
# %run "../chapter 2 - initial commitment transaction/initial commitment transaction v3.ipynb"
# Out:
# 2026-04-07T14:25:26.910000Z TestFramework (INFO): PRNG seed is: 4218969670666729517
# 2026-04-07T14:25:26.913000Z TestFramework (INFO): Initializing test directory /tmp/bitcoin_func_test_89ghvc5_
# 🟢 New TestShell started. Block height: 0
# Alice Per Commitment Seed 34b581ec20bf2c6cae3d4d4dcbfddc8a3727a1e9a57c55f3520e770607898c06
# Bob Per Commitment Seed 89c994b3ddad4698acee71e42d8bcace48eea739caaba371eb110e77663ec56d
# Alice Payment BasePoint:  025f892a06124391e2f38ce35d943cdc09f63e203330dbd9cb6113a903e0738458
# Bob Payment BasePoint:  02f98efd3f2b2fbe7bd83c419f5f64f8280798b8a9175fdb77c0091bbb95c79506
# To obscure commitment number 0xb433fd43a66f
# Alice funding pubkey: 5e63dec8d51cfdf2206a18f167add096230136d3a1cf5ff46f3650698b0545f2
# Alice funding privkey: 2a0606d477f0ad77c98ad9a6ad2482c069eab5d43dd9b47f447cca28b5abdd75
# Alice funding address: bcrt1pte3aajx4rn7lygr2rrck0twsjc3szdkn5884lar0xegxnzc9gheqe5mk8s
# Alice sweeper pubkey: 9200623157af7b443920f97ead26fc0bffb78bfa63b4ae9dd8fa8b7f474694de
# Alice sweeper privkey: 2424394946e17b8bbd0c7b2cd649249b1b868842c36a4c50c95ac453dbca7306
# Alice sweeper address: bcrt1pjgqxyv2h4aa5gwfql9l26fhup0lm0zl6vw62a8wcl29h736xjn0qj3k02d
# Bob funding pubkey: 354f898bd9c30b8fb578c7a4606310b6459a6b9d5062d2618c9daab6d65842df
# Bob funding privkey: 3b20c817aea827754427be5985758f1fc000e0e11fd82cdab19170c6b079110d
# Bob funding address: bcrt1px48cnz7ecv9cldtcc7jxqccskeze56ua2p3dycvvnk4td4jcgt0s2pfwy3
# Bob sweeper pubkey: cca4a0a2a059409f6135f86749523e08e129fa2c74f81b699f5c63ef2524c726
# Bob sweeper privkey: 12872f7e13afed2061ab85b78843ecfe734d1ece2aca363fd459baed40875bdb
# Bob sweeper address: bcrt1pejj2pg4qt9qf7cf4lpn5j537prsjn73vwnupk6vlt3377ffycunqam022l
# Alice Change pubkey: 61eb024a014320225db61b6ab70ec9c5a1825cefd63a0e175ec0d355942eca43
# Alice Change privkey: dd897a83dbe7c5259c5451ed491f5b21419217a706bbfe1955fe561bd6d4c8ac
# Alice Change address: bcrt1pv84syjspgvszyhdkrd4twrkfckscyh806caqu967crf4t9pwefps3p9nh9
# Bob Change pubkey: c97b86f32700e0ae06a5b179bad64145c8cf98db164a7419e3f8f753f210a7e7
# Bob Change privkey: 33b59a095514bd4cfbb3e8678102c8ee0ff7f51cb104e452d2f2534ec1b1aac1
# Bob Change address: bcrt1pe9acdue8qrs2up49k9um44jpghyvlxxmze98gx0rlrm48uss5lnsqrzndt
# Transaction creating Alice UTXO: 95b086731e7fbe39aa9fedb5d20e40366e599c8c66d47b5791fe5db6f532fd98
# {
#   "txid": "95b086731e7fbe39aa9fedb5d20e40366e599c8c66d47b5791fe5db6f532fd98",
#   "hash": "5cab0073aba842cd76f21a13d4b554a1c959e5eda9beffab062d2332ad2750c5",
#   "version": 2,
#   "size": 375,
#   "vsize": 294,
#   "weight": 1173,
#   "locktime": 101,
#   "vin": [
#     {
#       "txid": "d61aca66e0285f0f26dcb6e38956ff8139d9f9584dc300801ac551184ae2ae77",
#       "vout": 0,
#       "scriptSig": {
#         "asm": "",
#         "hex": ""
#       },
#       "txinwitness": [
#         "3044022004209cab915e782af70e1072681cf344823d40ea727be65aa44048d4a58df3be02207069038f2f8a9d7e21f85408561d63bf4943698ca63675557b8237143c0f506801",
#         "036b30fa6d4cc3f41cee135373aacb8a42ba81e452683a8a249a44263c1349222c"
#       ],
#       "sequence": 4294967293
#     }
#   ],
#   "vout": [
#     {
#       "value": "0.10000000",
#       "n": 0,
#       "scriptPubKey": {
#         "asm": "1 9200623157af7b443920f97ead26fc0bffb78bfa63b4ae9dd8fa8b7f474694de",
#         "desc": "rawtr(9200623157af7b443920f97ead26fc0bffb78bfa63b4ae9dd8fa8b7f474694de)#evsux2u9",
#         "hex": "51209200623157af7b443920f97ead26fc0bffb78bfa63b4ae9dd8fa8b7f474694de",
#         "address": "bcrt1pjgqxyv2h4aa5gwfql9l26fhup0lm0zl6vw62a8wcl29h736xjn0qj3k02d",
#         "type": "witness_v1_taproot"
#       }
#     },
#     {
#       "value": "47.79994120",
#       "n": 1,
#       "scriptPubKey": {
#         "asm": "1 b1005b57b6026c4b2dfdff1197831619b7be1c716ed92bf2ee11145f1ce4087a",
#         "desc": "rawtr(b1005b57b6026c4b2dfdff1197831619b7be1c716ed92bf2ee11145f1ce4087a)#6tns36nu",
#         "hex": "5120b1005b57b6026c4b2dfdff1197831619b7be1c716ed92bf2ee11145f1ce4087a",
#         "address": "bcrt1pkyq9k4akqfkykt0aluge0qckrxmmu8r3dmvjhuhwzy29788yppaqutt6g8",
#         "type": "witness_v1_taproot"
#       }
#     },
#     {
#       "value": "1.00000000",
#       "n": 2,
#       "scriptPubKey": {
#         "asm": "1 5e63dec8d51cfdf2206a18f167add096230136d3a1cf5ff46f3650698b0545f2",
#         "desc": "rawtr(5e63dec8d51cfdf2206a18f167add096230136d3a1cf5ff46f3650698b0545f2)#4t8cg245",
#         "hex": "51205e63dec8d51cfdf2206a18f167add096230136d3a1cf5ff46f3650698b0545f2",
#         "address": "bcrt1pte3aajx4rn7lygr2rrck0twsjc3szdkn5884lar0xegxnzc9gheqe5mk8s",
#         "type": "witness_v1_taproot"
#       }
#     },
#     {
#       "value": "1.00000000",
#       "n": 3,
#       "scriptPubKey": {
#         "asm": "1 354f898bd9c30b8fb578c7a4606310b6459a6b9d5062d2618c9daab6d65842df",
#         "desc": "rawtr(354f898bd9c30b8fb578c7a4606310b6459a6b9d5062d2618c9daab6d65842df)#ckgvn9a4",
#         "hex": "5120354f898bd9c30b8fb578c7a4606310b6459a6b9d5062d2618c9daab6d65842df",
#         "address": "bcrt1px48cnz7ecv9cldtcc7jxqccskeze56ua2p3dycvvnk4td4jcgt0s2pfwy3",
#         "type": "witness_v1_taproot"
#       }
#     },
#     {
#       "value": "0.10000000",
#       "n": 4,
#       "scriptPubKey": {
#         "asm": "1 cca4a0a2a059409f6135f86749523e08e129fa2c74f81b699f5c63ef2524c726",
#         "desc": "rawtr(cca4a0a2a059409f6135f86749523e08e129fa2c74f81b699f5c63ef2524c726)#xfyyw3ua",
#         "hex": "5120cca4a0a2a059409f6135f86749523e08e129fa2c74f81b699f5c63ef2524c726",
#         "address": "bcrt1pejj2pg4qt9qf7cf4lpn5j537prsjn73vwnupk6vlt3377ffycunqam022l",
#         "type": "witness_v1_taproot"
#       }
#     }
#   ],
#   "hex": "..."
# }
# Alice transaction to spend: 95b086731e7fbe39aa9fedb5d20e40366e599c8c66d47b5791fe5db6f532fd98:2
# Alice MuSig2 pubkey: b388cc1ef2591476c830a21b5021200df53c64a4d35cb03b7d162ea83c725889
# Alice MuSig2 privkey: 95b407baa4d29368497ec40d81f1569fa2a6326f655a8e8c30cb4d044664fbf5
# Bob MuSig2 pubkey: 763ac5293202d433e5673a4b20a540a297fa3e033dece26fee3bfb3cc70f2171
# Bob MuSig2 privkey: ff823c0c05f5c6495c0a7cc2b2638576fb65e855352b909a627be82bef49a47a
# Aggregate musig2 pubkey: 4f243c0d01935e2661aad761404075b211c335f3703fc5ae73e07db89d981b9f
# Channel funding musig2 output address: bcrt1pfujrcrgpjd0zvcd26as5qsr4kgguxd0nwqluttnnup7m38vcrw0sx96vjj
# unsigned_tx:  
# {
#   "txid": "db4c370583f48f484a9f0f9c8110dca961c9a7b7b796b65699ed5ae9513db53c",
#   "hash": "db4c370583f48f484a9f0f9c8110dca961c9a7b7b796b65699ed5ae9513db53c",
#   "version": 2,
#   "size": 137,
#   "vsize": 137,
#   "weight": 548,
#   "locktime": 0,
#   "vin": [
#     {
#       "txid": "95b086731e7fbe39aa9fedb5d20e40366e599c8c66d47b5791fe5db6f532fd98",
#       "vout": 2,
#       "scriptSig": {
#         "asm": "",
#         "hex": ""
#       },
#       "sequence": 4294967295
#     }
#   ],
#   "vout": [
#     {
#       "value": "0.01000000",
#       "n": 0,
#       "scriptPubKey": {
#         "asm": "1 4f243c0d01935e2661aad761404075b211c335f3703fc5ae73e07db89d981b9f",
#         "desc": "rawtr(4f243c0d01935e2661aad761404075b211c335f3703fc5ae73e07db89d981b9f)#7e8jthvm",
#         "hex": "51204f243c0d01935e2661aad761404075b211c335f3703fc5ae73e07db89d981b9f",
#         "address": "bcrt1pfujrcrgpjd0zvcd26as5qsr4kgguxd0nwqluttnnup7m38vcrw0sx96vjj",
#         "type": "witness_v1_taproot"
#       }
#     },
#     {
#       "value": "0.98999700",
#       "n": 1,
#       "scriptPubKey": {
#         "asm": "1 61eb024a014320225db61b6ab70ec9c5a1825cefd63a0e175ec0d355942eca43",
#         "desc": "rawtr(61eb024a014320225db61b6ab70ec9c5a1825cefd63a0e175ec0d355942eca43)#gk8aaskg",
#         "hex": "512061eb024a014320225db61b6ab70ec9c5a1825cefd63a0e175ec0d355942eca43",
#         "address": "bcrt1pv84syjspgvszyhdkrd4twrkfckscyh806caqu967crf4t9pwefps3p9nh9",
#         "type": "witness_v1_taproot"
#       }
#     }
#   ]
# }
# signed tx:  ...
# {
#   "txid": "db4c370583f48f484a9f0f9c8110dca961c9a7b7b796b65699ed5ae9513db53c",
#   "hash": "3490fe36bdf312af65e20c299aa6e25c0f3d61e3f95d19d25c8e7aa04d49391e",
#   "version": 2,
#   "size": 205,
#   "vsize": 154,
#   "weight": 616,
#   "locktime": 0,
#   "vin": [
#     {
#       "txid": "95b086731e7fbe39aa9fedb5d20e40366e599c8c66d47b5791fe5db6f532fd98",
#       "vout": 2,
#       "scriptSig": {
#         "asm": "",
#         "hex": ""
#       },
#       "txinwitness": [
#         "5e683d8d4d05ff9c72376df5846bdd45b38732a4c6dcbf2738aee6e3c73d7cb4eb8f8d281a1a565abc3398859adb8dc768cab4dae65f29839197886392a922b7"
#       ],
#       "sequence": 4294967295
#     }
#   ],
#   "vout": [
#     {
#       "value": "0.01000000",
#       "n": 0,
#       "scriptPubKey": {
#         "asm": "1 4f243c0d01935e2661aad761404075b211c335f3703fc5ae73e07db89d981b9f",
#         "desc": "rawtr(4f243c0d01935e2661aad761404075b211c335f3703fc5ae73e07db89d981b9f)#7e8jthvm",
#         "hex": "51204f243c0d01935e2661aad761404075b211c335f3703fc5ae73e07db89d981b9f",
#         "address": "bcrt1pfujrcrgpjd0zvcd26as5qsr4kgguxd0nwqluttnnup7m38vcrw0sx96vjj",
#         "type": "witness_v1_taproot"
#       }
#     },
#     {
#       "value": "0.98999700",
#       "n": 1,
#       "scriptPubKey": {
#         "asm": "1 61eb024a014320225db61b6ab70ec9c5a1825cefd63a0e175ec0d355942eca43",
#         "desc": "rawtr(61eb024a014320225db61b6ab70ec9c5a1825cefd63a0e175ec0d355942eca43)#gk8aaskg",
#         "hex": "512061eb024a014320225db61b6ab70ec9c5a1825cefd63a0e175ec0d355942eca43",
#         "address": "bcrt1pv84syjspgvszyhdkrd4twrkfckscyh806caqu967crf4t9pwefps3p9nh9",
#         "type": "witness_v1_taproot"
#       }
#     }
#   ]
# }
# funding_channel_txid:  db4c370583f48f484a9f0f9c8110dca961c9a7b7b796b65699ed5ae9513db53c
# Commitment Number Osbscured 0xb433fd43a66f
# Shared Anchor ScriptPubKey: 51024e73
# Alice Delayed PubKey: d6363615b3d00361158c0f48a4ef81ea12e214e8d56e24098759f6b4267dca8b
# Bob Revocation PubKey: 5460add4edf0961bfcc6288be0241114d7d90005db28753d835f2353f1529710
# unsigned_tx:  03000000013cb53d51e95aed9956b696b7b7a7c961a9dc10819c0f9f4a488ff48305374cdb0000000000fd33b48002f0000000000000000451024e7350410f0000000000225120e0d1d0ee66892a37745dd6f36a46dccf7fab752bec7f2579f0e147cd5707a13e6fa64320
# {
#   "txid": "2fd7fc57da50c3921403e2303989e8818fd5e9e28eca1e709c81e17448b2c63d",
#   "hash": "2fd7fc57da50c3921403e2303989e8818fd5e9e28eca1e709c81e17448b2c63d",
#   "version": 3,
#   "size": 107,
#   "vsize": 107,
#   "weight": 428,
#   "locktime": 541304431,
#   "vin": [
#     {
#       "txid": "db4c370583f48f484a9f0f9c8110dca961c9a7b7b796b65699ed5ae9513db53c",
#       "vout": 0,
#       "scriptSig": {
#         "asm": "",
#         "hex": ""
#       },
#       "sequence": 2159293437
#     }
#   ],
#   "vout": [
#     {
#       "value": "0.00000240",
#       "n": 0,
#       "scriptPubKey": {
#         "asm": "1 29518",
#         "desc": "addr(bcrt1pfeesnyr2tx)#swxgse0y",
#         "hex": "51024e73",
#         "address": "bcrt1pfeesnyr2tx",
#         "type": "anchor"
#       }
#     },
#     {
#       "value": "0.00999760",
#       "n": 1,
#       "scriptPubKey": {
#         "asm": "1 e0d1d0ee66892a37745dd6f36a46dccf7fab752bec7f2579f0e147cd5707a13e",
#         "desc": "rawtr(e0d1d0ee66892a37745dd6f36a46dccf7fab752bec7f2579f0e147cd5707a13e)#4wlgrwnj",
#         "hex": "5120e0d1d0ee66892a37745dd6f36a46dccf7fab752bec7f2579f0e147cd5707a13e",
#         "address": "bcrt1purgapmnx3y4rwaza6mek53kueal6kafta3lj270su9ru64c85ylqfkajju",
#         "type": "witness_v1_taproot"
#       }
#     }
#   ]
# }
# aggregated Schnorr verifies? True
# signed tx:  
# {
#   "txid": "2fd7fc57da50c3921403e2303989e8818fd5e9e28eca1e709c81e17448b2c63d",
#   "hash": "433325f702ae4684fbadcddeaf7aedcedf8af87f4a1604467e5cad2fd4ebe1b4",
#   "version": 3,
#   "size": 175,
#   "vsize": 124,
#   "weight": 496,
#   "locktime": 541304431,
#   "vin": [
#     {
#       "txid": "db4c370583f48f484a9f0f9c8110dca961c9a7b7b796b65699ed5ae9513db53c",
#       "vout": 0,
#       "scriptSig": {
#         "asm": "",
#         "hex": ""
#       },
#       "txinwitness": [
#         "5d285b0484bffcbe00335e9f955caaa5373218a2f52a14bde12e7bb33fc6a5dd71dfcc10ca72891cc3ff6c46873f3f9907100c2bdd87bf331d7a368b278073c6"
#       ],
#       "sequence": 2159293437
#     }
#   ],
#   "vout": [
#     {
#       "value": "0.00000240",
#       "n": 0,
#       "scriptPubKey": {
#         "asm": "1 29518",
#         "desc": "addr(bcrt1pfeesnyr2tx)#swxgse0y",
#         "hex": "51024e73",
#         "address": "bcrt1pfeesnyr2tx",
#         "type": "anchor"
#       }
#     },
#     {
#       "value": "0.00999760",
#       "n": 1,
#       "scriptPubKey": {
#         "asm": "1 e0d1d0ee66892a37745dd6f36a46dccf7fab752bec7f2579f0e147cd5707a13e",
#         "desc": "rawtr(e0d1d0ee66892a37745dd6f36a46dccf7fab752bec7f2579f0e147cd5707a13e)#4wlgrwnj",
#         "hex": "5120e0d1d0ee66892a37745dd6f36a46dccf7fab752bec7f2579f0e147cd5707a13e",
#         "address": "bcrt1purgapmnx3y4rwaza6mek53kueal6kafta3lj270su9ru64c85ylqfkajju",
#         "type": "witness_v1_taproot"
#       }
#     }
#   ]
# }
# [{'txid': '2fd7fc57da50c3921403e2303989e8818fd5e9e28eca1e709c81e17448b2c63d', 'wtxid': '433325f702ae4684fbadcddeaf7aedcedf8af87f4a1604467e5cad2fd4ebe1b4', 'allowed': False, 'reject-reason': 'min relay fee not met', 'reject-details': 'min relay fee not met, 0 < 124'}]

# %% [markdown]
# ## HTLC (Hashed Time Locked Contracts)
#
# Once the channel is established, it can be used to make payments via HTLCs (Hashed Time-Locked Contracts).
#
# Updates to the channel state are sent in batches: one or more `update_ messages` are exchanged before a `commitment_signed` message is sent. In the diagram below, we show only one`update_message` per `commitment_signed` for simplicity:
#
#     +-----------+                                                      +-----------+
#     |           |                                                      |           |
#     |           |------ channel_reestablished (next local nonce) ----->|           |
#     |           |<----- channel_reestablished (next local nonce) ------|           |
#     |   Alice   |                                                      |    Bob    |
#     |           |                                                      |           |
#     |           |----------------- update_add_htlc ------------------->|           |
#     |           |----- commitment_signed (partial sig) (jit nonce) --->|           |
#     |           |<--------- revoke_and_ack (next local nonce) ---------|           |
#     |           |<---- commitment_signed  (partial sig) (jit nonce) ---|           |
#     |           |---------- revoke_and_ack (next local nonce) -------->|           |
#     |           |                                                      |           |
#     |           |                                                      |           |
#     +-----------+                                                      +-----------+
#
# The messages are defined in the [BOLT 2](https://github.com/lightning/bolts/blob/master/02-peer-protocol.md#adding-an-htlc-update_add_htlc).
#
# ### The `update_add_htlc` Message
#
# Alice sends the `update_add_htlc`  message to Bob, which includes the details of the HTLC being offered:
# - channel_id
# - id (htlc counter starting in zero)
# - amount_msat
# - payment_hash
# - cltv_expiry
# - onion_routing_packet
#
# ### The `commitment_signed` Message
#
# Shortly after sending the `update_add_htlc` message, Alice commits to the new channel state so that the HTLC can be safely included by Bob. At this point, Bob has the HTLC information and has constructed a new commitment transaction, but he hasn't yet received Alice's signature for it.
#
# Alice sends a `commitment_signed`message to Bob, which includes her signature for the new commitment transaction as well as the HTLC output it contains:
# - channel_id
# - signature
# - num_htlcs
# - partial_signature_with_nonce
#
# ### The `revoke_and_ack` Message
#
# Now that Bob has a new signed commitment, he needs to acknowledge it and revoke the previous one. He does this by sending a`revoke_and_ack` message to Alice:
#
# - channel_id
# - per_commitment_secret
# - next_per_commitment_point
# - nonce
#
# Finally, Bob sends a `commitment_signed` message to Alice, and Alice responds with a `revoke_and_ack` message. At this point, both parties have fully signed the new commitment transaction.

# %% [markdown]
# ### The Unsigned Transaction
#
# ### The Input
#
# The input is the channel funding transaction.

# %%
# VERSION
# version '3' indicates that we are using V3 TRUC (Topologically Restricted Until Confirmation) transactions
version = bytes.fromhex("0300 0000")

# MARKER (new to segwit)
marker = bytes.fromhex("00")

# FLAG (new to segwit)
flag = bytes.fromhex("01")

# INPUTS
# We have just 1 input
input_count = bytes.fromhex("01")

# Convert txid and index to bytes (little endian)
txid = (bytes.fromhex(funding_channel_txid))[::-1]
funding_channel_index = 0
index = funding_channel_index.to_bytes(4, byteorder="little", signed=False)

# For the unsigned transaction we use an empty scriptSig
scriptsig = bytes.fromhex("")

# sequence: upper 8 bits are 0x80, lower 24 bits are the upper 24 bits of the obscured commitment number
# Commitment number of the second commitment transaction.
commitment_number = 1
# obscured commitment number is result of xor operation 
commitment_number_obscured = lower48_to_obscure ^ commitment_number
# Extract the upper 24 bits of the obscured commitment number
upper_24_bits = (commitment_number_obscured >> 24) & 0xFFFFFF
# Combine the upper 8 bits (0x80) with the lower 24 bits (upper 24 of obscured number)
sequence = (0x80 << 24) | upper_24_bits
# Convert to bytes (byte, big-endian)
sequence = sequence.to_bytes(4, byteorder='big')
# Convert to little-endian 
sequence = sequence[::-1]

inputs = (
    txid
    + index
    + varint_len(scriptsig)
    + scriptsig
    + sequence
)

print("Commitment Number Osbscured", hex(commitment_number_obscured))
# Out:
# Commitment Number Osbscured 0xb433fd43a66e

# %% [markdown]
# ### The Outputs
#
# Let’s assume Alice is sending 0.5 million satoshis to Bob, for this reason Alice node is offering an HTLC to Bob's node of this value.

# %% [markdown]
# For this alice commitment transaction we must add an offered HTLC otuput and to remote anchor output.
#
# #### The Offered HTLC otuput
#
# The offered HTLC otuput pays out to the remote party if they reveal the pre-image to a given hash before a certain CLTV timeout. After the timeout, the local party will be able to claim the output via the htlc-timeout transaction. If the commitment transaction is a revoked state, then the remote party should be able to sweep the output at any time.
#
#
#
#     +------+---------------+
#     | OP_1 |       Q       |
#     +------+---------------+
#                    ^
#                    |   +-------------------+
#                     ---| P(revocation) + T |
#                        +-------------------+
#                                          ^
#                                          |
#                                    +-----------+
#                                    | T = t * G |
#                                    +-----------+
#                                          ^
#                                          |
#      +---+   +-------------------------------------------------------+
#      | t | = | TaggedHash ("Taptweak", P(revocation) || script_root) |
#      +---+   +-------------------------------------------------------+
#                                                              ^
#                                                              |
#                                                           +-----+
#                           ------------------------------> | hAB |<------------------
#                          |                                +-----+                   |
#                          |                                                          |
#                          |                                                          |
#                       +----+                                                     +----+
#                       | hA |                                                     | hB |
#                       +----+                                                     +----+
#                          ^                                                          ^
#                          |                                                          |
#       +---------------------------------+                                           |
#       | P(local_htlc) OP_CHECKSIGVERIFY |                                           |
#       |                                 |                                           |
#       | P(remote_htlc) OP_CHECKSIG      |                                           |
#       +---------------------------------+                                           |
#       +-------------------------------------------------------------------------------+
#       | P(remote_htlc) OP_CHECKSIGVERIFY                                              |
#       | OP_SIZE 32 OP_EQUALVERIFY OP_HASH160 <RIPEMD160(payment_hash)> OP_EQUAL       |
#       +-------------------------------------------------------------------------------+

# %%
# Create Alice per-commitment
alice_per_commitment = per_commitment(alice_per_commitment_seed, commitment_number)
# Create Bob per-commitment
bob_per_commitment = per_commitment(bob_per_commitment_seed, commitment_number)

# Create Alice Delayed Public Key
alice_delayed_pubkey = derivate_key(alice_node_seed, family=4, channel_index=0).get_pubkey(alice_per_commitment.get_pub())
print(f"Alice Delayed PubKey: {alice_delayed_pubkey.get_bytes(bip340=True).hex()}")

# Create Bob Local Public Key which in this case is the P(remote) for Alice
bob_payment_pubkey = bob_payment.get_pubkey(bob_per_commitment.get_pub())
print(f"Bob Payment PubKey: {bob_payment_pubkey.get_bytes(bip340=True).hex()}")

# Create Bob Revocation Public Key
bob_revocation_pubkey = derivate_revocation_key(bob_node_seed, channel_index=0).get_pubkey(alice_per_commitment.get_pub())
print(f"Bob Revocation PubKey: {bob_revocation_pubkey.get_bytes(bip340=True).hex()}")

# Create Alice HTLC Public Key
alice_htlc_pubkey = derivate_key(alice_node_seed, family=2, channel_index=0).get_pubkey(alice_per_commitment.get_pub())
print(f"Alice HTLC PubKey: {alice_htlc_pubkey.get_bytes(bip340=True).hex()}")

# Create Bob HTLC Public Key
bob_htlc_pubkey = derivate_key(bob_node_seed, family=2, channel_index=0).get_pubkey(bob_per_commitment.get_pub())
print(f"Bob HTLC PubKey: {bob_htlc_pubkey.get_bytes(bip340=True).hex()}")

# Outputs for Alice Second Commitment Transaction
# 0x03 outputs
output_count = bytes.fromhex("03")

# OFFERED HTLC OUTPUT
# HTLC output amount
htlc_output_value_satoshis = 500000
htlc_output_value = htlc_output_value_satoshis.to_bytes(8, byteorder="little", signed=False)

# Create the leaf scripts A and B
# Leaf script A: P(local_htlc) OP_CHECKSIGVERIFY P(remote_htlc) OP_CHECKSIG
scriptA = CScript([alice_htlc_pubkey.get_bytes(bip340=True), OP_CHECKSIGVERIFY, bob_htlc_pubkey.get_bytes(bip340=True), OP_CHECKSIG])

# Leaf script B: P(remote_htlc) OP_CHECKSIGVERIFY OP_SIZE 32 OP_EQUALVERIFY OP_HASH160 <RIPEMD160(payment_hash)> OP_EQUAL

# We use a dummy payment_hash here. In a real scenario, this would be the hash of the preimage for the HTLC.
# And would be sent in the message update_add_htlc.
sha = sha256(b'payment').digest()
payment_hash = hashlib.new("ripemd160", sha).digest()

scriptB = CScript([bob_htlc_pubkey.get_bytes(bip340=True), OP_CHECKSIGVERIFY, OP_SIZE, bytes.fromhex("20"), OP_EQUALVERIFY, OP_HASH160, payment_hash, OP_EQUAL])

# Compute TapLeaves A and B
# Method: ser_string(data) is a function which adds compactsize to input data.
hash_inputA = TAPSCRIPT_VER + ser_string(scriptA)
hash_inputB = TAPSCRIPT_VER + ser_string(scriptB)
htlc_taggedhash_leafA = tagged_hash("TapLeaf", hash_inputA)
htlc_taggedhash_leafB = tagged_hash("TapLeaf", hash_inputB)

print("\ntapleaf_hash:", htlc_taggedhash_leafA.hex())
print("\ntapleaf_hash:", htlc_taggedhash_leafB.hex())

# Method: Returns tapbranch hash. Child hashes are lexographically sorted and then concatenated.
# l: tagged hash of left child
# r: tagged hash of right child
def tapbranch_hash(l, r):
    return tagged_hash("TapBranch", b''.join(sorted([l,r])))

# Compute Internal node TapBranch AB
root_ab = tapbranch_hash(htlc_taggedhash_leafA, htlc_taggedhash_leafB)
print("\ntapbranch_hash (root_ab):", root_ab.hex())

# Compute TapTweak
taptweak = tagged_hash("TapTweak", bob_revocation_pubkey.get_bytes(bip340=True) + root_ab)
bob_revocation_pubkey_tweaked = bob_revocation_pubkey.tweak_add(taptweak)
print("\ntaptweak:", taptweak.hex())

# scriptPubKey P2TR: OP_1 (0x51) + PUSH32 (0x20) + xonly(32B)
alice_offered_htlc_spk = bytes.fromhex("51") + varint_len(bob_revocation_pubkey_tweaked.get_bytes(bip340=True)) + bob_revocation_pubkey_tweaked.get_bytes(bip340=True)
# Out:
# Alice Delayed PubKey: dc5cd4cbc27d9856a98bdf5ab9da85023f20c960c52c93b7e36d40a04b5cfbe5
# Bob Payment PubKey: 8f16659036b06b785dd82ec3ac4d5518c2c11e2e101612e6dc983bfeb6dc7ba5
# Bob Revocation PubKey: c39a6b0cffa569f243cec8252a1e5f93b4b072247ff18773917b72fb6341f608
# Alice HTLC PubKey: 7546c6ab3a8c005ce24e9feb7154fd35b62ac0f9125beb5e692d4d912a95de77
# Bob HTLC PubKey: 7bd8383df06640c0efe760bb2bac1a1585bdc664e6f1cb61c41a76a6f2be3484
#
# tapleaf_hash: 509fbe809f2233d8daa3bca96c2735a7f7a1bd75eb48976978029ac95cd0fd13
#
# tapleaf_hash: 2fbd0ee9ad97225e09e436e3e9965d3b1bea9c935aa04af360d50ae3f8740231
#
# tapbranch_hash (root_ab): e05d9627b7af510f09ec846f528138e47bf0b096c11992fd7d6f45eecb8cb6c7
#
# taptweak: 1f907e5158b5d659d1d86af0f739b3cbdc8aeec9cfc8007874c440aa5a003038

# %%
# TO LOCAL OUTPUT
# to local output amount
to_local_value_sat = channel_value_sat - anchor_output_value_satoshis - htlc_output_value_satoshis
to_local_value = to_local_value_sat.to_bytes(8, byteorder="little", signed=False)

# Create the leaf scripts A and B
# P(local_delayed) OP_CHECKSIG to_self_delay OP_CSV OP_DROP
to_self_delay = 144
script = CScript([alice_delayed_pubkey.get_bytes(bip340=True), OP_CHECKSIGVERIFY, to_self_delay.to_bytes(2,"big"), OP_CHECKSEQUENCEVERIFY])

# Compute TapLeaves
# Method: ser_string(data) is a function which adds compactsize to input data.
hash_input = TAPSCRIPT_VER + ser_string(script)
taggedhash_leaf = tagged_hash("TapLeaf", hash_input)

# Compute TapTweak
taptweak = tagged_hash("TapTweak", bob_revocation_pubkey.get_bytes(bip340=True) + taggedhash_leaf)
bob_revocation_pubkey_tweaked = bob_revocation_pubkey.tweak_add(taptweak)

# scriptPubKey P2TR: OP_1 (0x51) + PUSH32 (0x20) + xonly(32B)
alice_to_local_spk = bytes.fromhex("51") + varint_len(bob_revocation_pubkey_tweaked.get_bytes(bip340=True)) + bob_revocation_pubkey_tweaked.get_bytes(bip340=True)

outputs = (
    anchor_output_value
    + varint_len(shared_anchor_spk)
    + shared_anchor_spk
    + to_local_value
    + varint_len(alice_to_local_spk)
    + alice_to_local_spk
    + htlc_output_value
    + varint_len(alice_offered_htlc_spk)
    + alice_offered_htlc_spk
)

# Locktime: upper 8 bits are 0x20, lower 24 bits are the lower 24 bits of the obscured commitment number
# Extract the lower 24 bits of the obscured commitment number
lower_24_bits = commitment_number_obscured & 0xFFFFFF
# Combine the upper 8 bits (0x20) with the lower 24 bits (lower 24 of obscured number)
locktime = (0x20 << 24) | lower_24_bits
# Convert to bytes (1 byte, big-endian)
locktime = locktime.to_bytes(4, byteorder='big')
locktime = locktime[::-1]

unsigned_tx = (
    version
    + input_count
    + inputs
    + output_count
    + outputs
    + locktime
)
print("unsigned_tx: ", unsigned_tx.hex())

# Decode the unsigned transaction to verify it looks correct
decoded = node.decoderawtransaction(unsigned_tx.hex())
print(json.dumps(decoded, indent=2, default=str))
# Out:
# unsigned_tx:  
# {
#   "txid": "fdda081075922422e00e5dcb43309fafef5f76b3010f86e06d341c679d71745f",
#   "hash": "fdda081075922422e00e5dcb43309fafef5f76b3010f86e06d341c679d71745f",
#   "version": 3,
#   "size": 150,
#   "vsize": 150,
#   "weight": 600,
#   "locktime": 541304430,
#   "vin": [
#     {
#       "txid": "db4c370583f48f484a9f0f9c8110dca961c9a7b7b796b65699ed5ae9513db53c",
#       "vout": 0,
#       "scriptSig": {
#         "asm": "",
#         "hex": ""
#       },
#       "sequence": 2159293437
#     }
#   ],
#   "vout": [
#     {
#       "value": "0.00000240",
#       "n": 0,
#       "scriptPubKey": {
#         "asm": "1 29518",
#         "desc": "addr(bcrt1pfeesnyr2tx)#swxgse0y",
#         "hex": "51024e73",
#         "address": "bcrt1pfeesnyr2tx",
#         "type": "anchor"
#       }
#     },
#     {
#       "value": "0.00499760",
#       "n": 1,
#       "scriptPubKey": {
#         "asm": "1 618f0b1846e2d1e4efc7bd2251f6a970746e8f1d0192f9f2b369478fd2d631bf",
#         "desc": "rawtr(618f0b1846e2d1e4efc7bd2251f6a970746e8f1d0192f9f2b369478fd2d631bf)#tpf24puv",
#         "hex": "5120618f0b1846e2d1e4efc7bd2251f6a970746e8f1d0192f9f2b369478fd2d631bf",
#         "address": "bcrt1pvx8skxzxutg7fm78h539ra4fwp6xarcaqxf0nu4nd9rcl5kkxxls6ludls",
#         "type": "witness_v1_taproot"
#       }
#     },
#     {
#       "value": "0.00500000",
#       "n": 2,
#       "scriptPubKey": {
#         "asm": "1 d25da52cc19b2451d6162d1130f087658e6a2c388ea23c4a84bbb0451a01c4c7",
#         "desc": "rawtr(d25da52cc19b2451d6162d1130f087658e6a2c388ea23c4a84bbb0451a01c4c7)#ex6q2llj",
#         "hex": "5120d25da52cc19b2451d6162d1130f087658e6a2c388ea23c4a84bbb0451a01c4c7",
#         "address": "bcrt1p6fw62txpnvj9r4sk95gnpuy8vk8x5tpc363rcj5yhwcy2xspcnrs73ws9x",
#         "type": "witness_v1_taproot"
#       }
#     }
#   ]
# }

# %% [markdown]
# ## The sighash for the key path spend
#
# This is the “Schnorr key spend” case: you’re proving knowledge of the (tweaked) internal private key, with no script branch revealed. The message preimage is called msg_digest in [BIP-341](https://github.com/bitcoin/bips/blob/master/bip-0341.mediawiki).

# %%
index_of_this_input = bytes.fromhex("0000 0000")

# SIGHASH for key path spend
# See BIP-341 for details
sighash_epoch = bytes.fromhex("00")

# Control
hash_type = bytes.fromhex("00") # SIGHASH_DEFAULT (a new sighash type meaning implied SIGHASH_ALL)

# Transaction data
sha_prevouts = sha256(txid + index).digest()

sha_amounts = sha256(channel_value).digest()

# scriptPubKey P2TR: OP_1 (0x51) + PUSH32 (0x20) + xonly(32B)
sha_scriptpubkeys = sha256(
    varint_len(channel_spk)
    + channel_spk
).digest()

sha_sequences = sha256(sequence).digest()

sha_outputs = sha256(outputs).digest()

# Data about this input
spend_type = bytes.fromhex("00") # no annex present

sig_msg = (
    sighash_epoch
    + hash_type
    + version
    + locktime
    + sha_prevouts
    + sha_amounts
    + sha_scriptpubkeys
    + sha_sequences
    + sha_outputs
    + spend_type
    + index_of_this_input
)

tag_hash = sha256("TapSighash".encode()).digest()
sighash = sha256(tag_hash + tag_hash + sig_msg).digest()

# %% [markdown]
# ## Signing the sighash

# %%
# Build participants to sort them using the same rule used in pubkeys aggregation.
participants = [
    (pubkey_alice_musig2.get_bytes(bip340=False), privkey_alice_musig2.get_bytes(), alice_per_commitment_seed),
    (pubkey_bob_musig2.get_bytes(bip340=False),   privkey_bob_musig2.get_bytes(), bob_per_commitment_seed),
]

# Reorder participants to match the sorted pubkeys
pk_to_tuple = {pk: (pk, sk, pcs) for pk, sk, pcs in participants}
participants = [pk_to_tuple[pk] for pk in sorted_pubkeys]

# Alice and Bob generates its own nonce pair (secnonce, pubnonce)
secnonces, pubnonces = [], []
for pk, sk, pcs in participants:
    # Use per-commitment nonce for Alice to get deterministic results
    if pk == pubkey_alice_musig2.get_bytes(bip340=False):
        sec, pub = nonce_per_commitment(pcs, commitment_number, sk, pk, agg_pubkey_tweaked, sighash)
    else:
        sec, pub = nonce_gen(sk, pk, agg_pubkey_tweaked, sighash, None)
    secnonces.append(sec)
    pubnonces.append(pub)

# Alice and Bob has exchanged already the pubnonces, so they can agregate them and create the session context
agg_nonce = nonce_agg(pubnonces)
session = SessionContext(agg_nonce, sorted_pubkeys, [bip86_tweak], [True], sighash)

# Alice and Bob produces their partial signatures
psigs = [sign(sec, sk, session) for sec, (_, sk, _) in zip(secnonces, participants)]

# Each side verify the other’s partial signature before proceeding
for i, psig in enumerate(psigs):
    assert partial_sig_verify(psig, pubnonces, sorted_pubkeys, [bip86_tweak], [True], sighash, i)

# Each side combines partial signatures into the final Schnorr signature
agg_sig = partial_sig_agg(psigs, session)

# Sanity check: verify with BIP340 against the *tweaked* x-only key ---
ok = schnorr_verify(sighash, agg_pubkey_tweaked, agg_sig)
print("aggregated Schnorr verifies?", ok)
# Out:
# aggregated Schnorr verifies? True

# %% [markdown]
# ## The signed transaction

# %%
witness = (
    bytes.fromhex("01") # one stack item in the witness
    + varint_len(agg_sig)
    + agg_sig
)

# the final signed transaction
signed_alice_commitment_tx = (
    version
    + marker
    + flag
    + input_count
    + inputs
    + output_count
    + outputs
    + witness
    + locktime
)

print("signed tx: ",signed_alice_commitment_tx.hex())
# Decode the unsigned transaction to verify it looks correct
decoded_alice_commitment_tx = node.decoderawtransaction(signed_alice_commitment_tx.hex())
print(json.dumps(decoded_alice_commitment_tx, indent=2, default=str))

print(node.testmempoolaccept(rawtxs=[signed_alice_commitment_tx.hex()]))
# Out:
# signed tx:  ...
# {
#   "txid": "fdda081075922422e00e5dcb43309fafef5f76b3010f86e06d341c679d71745f",
#   "hash": "d649d7bcdde4c4ea5627fdcfe8fb3573d6513f4142115d050bdbeb51b06f1e78",
#   "version": 3,
#   "size": 218,
#   "vsize": 167,
#   "weight": 668,
#   "locktime": 541304430,
#   "vin": [
#     {
#       "txid": "db4c370583f48f484a9f0f9c8110dca961c9a7b7b796b65699ed5ae9513db53c",
#       "vout": 0,
#       "scriptSig": {
#         "asm": "",
#         "hex": ""
#       },
#       "txinwitness": [
#         "56b9edfd8ba41d50f7bf8de38b2b72419a2a56cb693aaf92ba32b6a567e5dc83f349067a8120e4972cfb277ef0facf570c2ef2c148dcba72f4bd8012d7477020"
#       ],
#       "sequence": 2159293437
#     }
#   ],
#   "vout": [
#     {
#       "value": "0.00000240",
#       "n": 0,
#       "scriptPubKey": {
#         "asm": "1 29518",
#         "desc": "addr(bcrt1pfeesnyr2tx)#swxgse0y",
#         "hex": "51024e73",
#         "address": "bcrt1pfeesnyr2tx",
#         "type": "anchor"
#       }
#     },
#     {
#       "value": "0.00499760",
#       "n": 1,
#       "scriptPubKey": {
#         "asm": "1 618f0b1846e2d1e4efc7bd2251f6a970746e8f1d0192f9f2b369478fd2d631bf",
#         "desc": "rawtr(618f0b1846e2d1e4efc7bd2251f6a970746e8f1d0192f9f2b369478fd2d631bf)#tpf24puv",
#         "hex": "5120618f0b1846e2d1e4efc7bd2251f6a970746e8f1d0192f9f2b369478fd2d631bf",
#         "address": "bcrt1pvx8skxzxutg7fm78h539ra4fwp6xarcaqxf0nu4nd9rcl5kkxxls6ludls",
#         "type": "witness_v1_taproot"
#       }
#     },
#     {
#       "value": "0.00500000",
#       "n": 2,
#       "scriptPubKey": {
#         "asm": "1 d25da52cc19b2451d6162d1130f087658e6a2c388ea23c4a84bbb0451a01c4c7",
#         "desc": "rawtr(d25da52cc19b2451d6162d1130f087658e6a2c388ea23c4a84bbb0451a01c4c7)#ex6q2llj",
#         "hex": "5120d25da52cc19b2451d6162d1130f087658e6a2c388ea23c4a84bbb0451a01c4c7",
#         "address": "bcrt1p6fw62txpnvj9r4sk95gnpuy8vk8x5tpc363rcj5yhwcy2xspcnrs73ws9x",
#         "type": "witness_v1_taproot"
#       }
#     }
#   ]
# }
# [{'txid': 'fdda081075922422e00e5dcb43309fafef5f76b3010f86e06d341c679d71745f', 'wtxid': 'd649d7bcdde4c4ea5627fdcfe8fb3573d6513f4142115d050bdbeb51b06f1e78', 'allowed': False, 'reject-reason': 'min relay fee not met', 'reject-details': 'min relay fee not met, 0 < 167'}]

# %% [markdown]
# ## Summary
#
# This chapter demonstrated how to create a Lightning channel commitment transaction with an in-flight HTLC using V3 (TRUC) from scratch:
#
# ### Alice's Commitment Transaction (V3) — Commitment #1
# - **Commitment number**: 1
# - **Transaction version**: 3 (TRUC — Topologically Restricted Until Confirmation)
# - **Three outputs**:
#   1. **Shared Anchor** (240 sats)
#   2. **To Local** (499,760 sats)
#   3. **Offered HTLC** (500,000 sats)
#
# ### Offered HTLC Output Structure
# The offered HTLC output is a P2TR where Bob's `revocation_pubkey` is used as the internal key, enabling a direct key-path spend in the penalty case. The script tree has two leaves:
#
# ```
# OP_1  <Q>
#       Q = revocation_pubkey + t*G
#       t = TaggedHash("TapTweak", revocation_pubkey || tapbranch(leafA,leafB))
# ```
#
# **Leaf A** — cooperative spend (both parties co-sign):
# ```
# <alice_htlc_pubkey> OP_CHECKSIGVERIFY
# <bob_htlc_pubkey>   OP_CHECKSIG
# ```
#
# **Leaf B** — payment reveal (Bob claims with preimage):
# ```
# <bob_htlc_pubkey> OP_CHECKSIGVERIFY
# OP_SIZE 32 OP_EQUALVERIFY
# OP_HASH160 <RIPEMD160(payment_hash)> OP_EQUAL
# ```
#
# - **Key-spend path** (internal key = `revocation_pubkey`): Bob can spend immediately via penalty if Alice broadcasts a revoked commitment state
# - **Leaf A path**: Both Alice and Bob co-sign to settle the HTLC cooperatively (e.g., via the HTLC-timeout transaction)
# - **Leaf B path**: Bob reveals the payment preimage to claim the HTLC output on-chain
#
# ### Key Takeaway
# Adding an in-flight HTLC to the commitment transaction introduces a third output whose Taproot structure encodes all three possible resolution paths: penalty (revocation key), cooperative timeout (both HTLC keys), and payment success (preimage reveal). The commitment transaction itself is still signed using MuSig2 key-path spend, keeping the on-chain footprint minimal.
